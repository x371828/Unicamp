# %%
from PIL import Image
import numpy as np
import os

# Corrigindo os diretórios para o notebook rodando em ms505/
input_base = os.path.join("original_data")
output_base = os.path.join("formated_data")

for split in ["Treino", "Teste"]:
    input_dir = os.path.join(input_base, split)
    output_dir = os.path.join(output_base, split)
    os.makedirs(output_dir, exist_ok=True)

    for filename in os.listdir(input_dir):
        if filename.endswith((".png", ".jpg", ".jpeg")):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            img = Image.open(input_path).convert("L")
            img.save(output_path)
            print(f"Processado: {input_path} -> {output_path}")
# Out:
# Processado: original_data/Treino/c006_002.png -> formated_data/Treino/c006_002.png
# Processado: original_data/Treino/c006_003.png -> formated_data/Treino/c006_003.png
# Processado: original_data/Treino/c007_006.png -> formated_data/Treino/c007_006.png
# Processado: original_data/Treino/c007_004.png -> formated_data/Treino/c007_004.png
# Processado: original_data/Treino/c006_001.png -> formated_data/Treino/c006_001.png
# Processado: original_data/Treino/c007_005.png -> formated_data/Treino/c007_005.png
# Processado: original_data/Treino/c007_001.png -> formated_data/Treino/c007_001.png
# Processado: original_data/Treino/c006_004.png -> formated_data/Treino/c006_004.png
# Processado: original_data/Treino/c006_005.png -> formated_data/Treino/c006_005.png
# Processado: original_data/Treino/c007_002.png -> formated_data/Treino/c007_002.png
# Processado: original_data/Treino/c006_006.png -> formated_data/Treino/c006_006.png
# Processado: original_data/Treino/c007_003.png -> formated_data/Treino/c007_003.png
# Processado: original_data/Treino/c005_001.png -> formated_data/Treino/c005_001.png
# Processado: original_data/Treino/c004_004.png -> formated_data/Treino/c004_004.png
# Processado: original_data/Treino/c004_005.png -> formated_data/Treino/c004_005.png
# Processado: original_data/Treino/c005_002.png -> formated_data/Treino/c005_002.png
# Processado: original_data/Treino/c004_006.png -> formated_data/Treino/c004_006.png
# Processado: original_data/Treino/c005_003.png -> formated_data/Treino/c005_003.png
# Processado: original_data/Treino/c004_002.png -> formated_data/Treino/c004_002.png
# Processado: original_data/Treino/c004_003.png -> formated_data/Treino/c004_003.png
# Processado: original_data/Treino/c005_006.png -> formated_data/Treino/c005_006.png
# Processado: original_data/Treino/c005_004.png -> formated_data/Treino/c005_004.png
# Processado: original_data/Treino/c004_001.png -> formated_data/Treino/c004_001.png
# Processado: original_data/Treino/c005_005.png -> formated_data/Treino/c005_005.png
# Processado: original_data/Treino/c008_003.png -> formated_data/Treino/c008_003.png
# Processado: original_data/Treino/c009_006.png -> formated_data/Treino/c009_006.png
# Processado: original_data/Treino/c010_005.png -> formated_data/Treino/c010_005.png
# Processado: original_data/Treino/c010_004.png -> formated_data/Treino/c010_004.png
# Processado: original_data/Treino/c001_001.png -> formated_data/Treino/c001_001.png
# Processado: original_data/Treino/c008_002.png -> formated_data/Treino/c008_002.png
# Processado: original_data/Treino/c009_005.png -> formated_data/Treino/c009_005.png
# Processado: original_data/Treino/c001_003.png -> formated_data/Treino/c001_003.png
# Processado: original_data/Treino/c010_006.png -> formated_data/Treino/c010_006.png
# Processado: original_data/Treino/c001_002.png -> formated_data/Treino/c001_002.png
# Processado: original_data/Treino/c009_004.png -> formated_data/Treino/c009_004.png
# Processado: original_data/Treino/c008_001.png -> formated_data/Treino/c008_001.png
# Processado: original_data/Treino/c008_005.png -> formated_data/Treino/c008_005.png
# Processado: original_data/Treino/c001_006.png -> formated_data/Treino/c001_006.png
# Processado: original_data/Treino/c010_003.png -> formated_data/Treino/c010_003.png
# Processado: original_data/Treino/c010_002.png -> formated_data/Treino/c010_002.png
# Processado: original_data/Treino/c009_001.png -> formated_data/Treino/c009_001.png
# Processado: original_data/Treino/c008_004.png -> formated_data/Treino/c008_004.png
# Processado: original_data/Treino/c008_006.png -> formated_data/Treino/c008_006.png
# Processado: original_data/Treino/c009_003.png -> formated_data/Treino/c009_003.png
# Processado: original_data/Treino/c001_005.png -> formated_data/Treino/c001_005.png
# Processado: original_data/Treino/c010_001.png -> formated_data/Treino/c010_001.png
# Processado: original_data/Treino/c001_004.png -> formated_data/Treino/c001_004.png
# Processado: original_data/Treino/c009_002.png -> formated_data/Treino/c009_002.png
# Processado: original_data/Treino/c003_006.png -> formated_data/Treino/c003_006.png
# Processado: original_data/Treino/c002_003.png -> formated_data/Treino/c002_003.png
# Processado: original_data/Treino/c002_002.png -> formated_data/Treino/c002_002.png
# Processado: original_data/Treino/c003_005.png -> formated_data/Treino/c003_005.png
# Processado: original_data/Treino/c002_001.png -> formated_data/Treino/c002_001.png
# Processado: original_data/Treino/c003_004.png -> formated_data/Treino/c003_004.png
# Processado: original_data/Treino/c002_005.png -> formated_data/Treino/c002_005.png
# Processado: original_data/Treino/c002_004.png -> formated_data/Treino/c002_004.png
# Processado: original_data/Treino/c003_001.png -> formated_data/Treino/c003_001.png
# Processado: original_data/Treino/c003_003.png -> formated_data/Treino/c003_003.png
# Processado: original_data/Treino/c002_006.png -> formated_data/Treino/c002_006.png
# Processado: original_data/Treino/c003_002.png -> formated_data/Treino/c003_002.png
# Processado: original_data/Teste/c007_007.png -> formated_data/Teste/c007_007.png
# Processado: original_data/Teste/c007_012.png -> formated_data/Teste/c007_012.png
# Processado: original_data/Teste/c002_009.png -> formated_data/Teste/c002_009.png
# Processado: original_data/Teste/c007_010.png -> formated_data/Teste/c007_010.png
# Processado: original_data/Teste/c007_011.png -> formated_data/Teste/c007_011.png
# Processado: original_data/Teste/c002_008.png -> formated_data/Teste/c002_008.png
# Processado: original_data/Teste/c003_009.png -> formated_data/Teste/c003_009.png
# Processado: original_data/Teste/c006_010.png -> formated_data/Teste/c006_010.png
# Processado: original_data/Teste/c006_011.png -> formated_data/Teste/c006_011.png
# Processado: original_data/Teste/c003_008.png -> formated_data/Teste/c003_008.png
# Processado: original_data/Teste/c006_007.png -> formated_data/Teste/c006_007.png
# Processado: original_data/Teste/c006_012.png -> formated_data/Teste/c006_012.png
# Processado: original_data/Teste/c004_010.png -> formated_data/Teste/c004_010.png
# Processado: original_data/Teste/c001_009.png -> formated_data/Teste/c001_009.png
# Processado: original_data/Teste/c001_008.png -> formated_data/Teste/c001_008.png
# Processado: original_data/Teste/c004_011.png -> formated_data/Teste/c004_011.png
# Processado: original_data/Teste/c008_009.png -> formated_data/Teste/c008_009.png
# Processado: original_data/Teste/c004_007.png -> formated_data/Teste/c004_007.png
# Processado: original_data/Teste/c004_012.png -> formated_data/Teste/c004_012.png
# Processado: original_data/Teste/c008_008.png -> formated_data/Teste/c008_008.png
# Processado: original_data/Teste/c005_007.png -> formated_data/Teste/c005_007.png
# Processado: original_data/Teste/c009_009.png -> formated_data/Teste/c009_009.png
# Processado: original_data/Teste/c009_008.png -> formated_data/Teste/c009_008.png
# Processado: original_data/Teste/c005_012.png -> formated_data/Teste/c005_012.png
# Processado: original_data/Teste/c005_010.png -> formated_data/Teste/c005_010.png
# Processado: original_data/Teste/c010_009.png -> formated_data/Teste/c010_009.png
# Processado: original_data/Teste/c010_008.png -> formated_data/Teste/c010_008.png
# Processado: original_data/Teste/c005_011.png -> formated_data/Teste/c005_011.png
# Processado: original_data/Teste/c005_008.png -> formated_data/Teste/c005_008.png
# Processado: original_data/Teste/c009_012.png -> formated_data/Teste/c009_012.png
# Processado: original_data/Teste/c010_011.png -> formated_data/Teste/c010_011.png
# Processado: original_data/Teste/c010_010.png -> formated_data/Teste/c010_010.png
# Processado: original_data/Teste/c009_007.png -> formated_data/Teste/c009_007.png
# Processado: original_data/Teste/c005_009.png -> formated_data/Teste/c005_009.png
# Processado: original_data/Teste/c009_011.png -> formated_data/Teste/c009_011.png
# Processado: original_data/Teste/c010_012.png -> formated_data/Teste/c010_012.png
# Processado: original_data/Teste/c010_007.png -> formated_data/Teste/c010_007.png
# Processado: original_data/Teste/c009_010.png -> formated_data/Teste/c009_010.png
# Processado: original_data/Teste/c008_011.png -> formated_data/Teste/c008_011.png
# Processado: original_data/Teste/c001_012.png -> formated_data/Teste/c001_012.png
# Processado: original_data/Teste/c001_007.png -> formated_data/Teste/c001_007.png
# Processado: original_data/Teste/c008_010.png -> formated_data/Teste/c008_010.png
# Processado: original_data/Teste/c008_012.png -> formated_data/Teste/c008_012.png
# Processado: original_data/Teste/c004_008.png -> formated_data/Teste/c004_008.png
# Processado: original_data/Teste/c001_011.png -> formated_data/Teste/c001_011.png
# Processado: original_data/Teste/c001_010.png -> formated_data/Teste/c001_010.png
# Processado: original_data/Teste/c004_009.png -> formated_data/Teste/c004_009.png
# Processado: original_data/Teste/c008_007.png -> formated_data/Teste/c008_007.png
# Processado: original_data/Teste/c003_012.png -> formated_data/Teste/c003_012.png
# Processado: original_data/Teste/c003_007.png -> formated_data/Teste/c003_007.png
# Processado: original_data/Teste/c003_011.png -> formated_data/Teste/c003_011.png
# Processado: original_data/Teste/c006_008.png -> formated_data/Teste/c006_008.png
# Processado: original_data/Teste/c006_009.png -> formated_data/Teste/c006_009.png
# Processado: original_data/Teste/c003_010.png -> formated_data/Teste/c003_010.png
# Processado: original_data/Teste/c002_011.png -> formated_data/Teste/c002_011.png
# Processado: original_data/Teste/c007_008.png -> formated_data/Teste/c007_008.png
# Processado: original_data/Teste/c007_009.png -> formated_data/Teste/c007_009.png
# Processado: original_data/Teste/c002_010.png -> formated_data/Teste/c002_010.png
# Processado: original_data/Teste/c002_012.png -> formated_data/Teste/c002_012.png
# Processado: original_data/Teste/c002_007.png -> formated_data/Teste/c002_007.png
